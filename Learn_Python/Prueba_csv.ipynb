# %%
import csv  
with open('people.csv') as f:
    reader = csv.reader(f   )
    for row in reader :
        print("Ap Paterno : {0}, Ap Materno : {1}, Nombre : {2}, Ciudad : {3}".format(row[0], row[1], row[2], row[3]))
# Out:
# Ap Paterno : Lucero, Ap Materno : Samuel, Nombre : Andres, Ciudad : ecu
